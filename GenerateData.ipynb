# %%
# %cd /content/drive/MyDrive/Algoritmos
# Out:
# /content/drive/MyDrive/Algoritmos

# %%
# !apt install octave
# !pip install oct2py

from IPython.display import clear_output
clear_output()

# %load_ext oct2py.ipython

# %%
# %%octave
#
# n_list = [8, 16, 32, 64, 128, 256, 512, 1024];
#
# for i=1:size(n_list, 2)
#   n = n_list(i);
#   A=gallery ('poisson', n);
#   filepng=['./data/data' mat2str(n) '.mat'];
#   mmwrite(filepng, A);
# end
